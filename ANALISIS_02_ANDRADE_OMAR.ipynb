# %% [markdown]
# # Dependencias

# %%
import pandas as pd
from babel.numbers import format_currency

# %% [markdown]
# # Lectura de datos

# %%
db = pd.read_csv('synergy_logistics_database.csv', index_col = "register_id")
db.head()
# Out:
#             direction origin destination  year      date product  \
# register_id
# 1             Exports  Japan       China  2015  31/01/15    Cars
# 2             Exports  Japan       China  2015  01/02/15    Cars
# 3             Exports  Japan       China  2015  02/02/15    Cars
# 4             Exports  Japan       China  2015  03/02/15    Cars
# 5             Exports  Japan       China  2015  04/02/15    Cars
#
#             transport_mode company_name  total_value
# register_id
# 1                      Sea        Honda     33000000
# 2                      Sea        Honda     16000000
# 3                      Sea        Honda     29000000
# 4                      Sea        Honda     14000000
# 5                      Sea        Honda     17000000

# %% [markdown]
# # Análisis del dataframe

# %%
db.shape # contamos el número de registros y campos
# Out:
# (19056, 9)

# %%
db.isnull().values.any() # Buscamos por algún valor nulo, ya que eso generaría sesgo
# Out:
# False

# %%
print(db.dtypes)
# Out:
# direction         object
# origin            object
# destination       object
# year               int64
# date              object
# product           object
# transport_mode    object
# company_name      object
# total_value        int64
# dtype: object

# %% [markdown]
# # Preguntas de Interés

# %% [markdown]
# ## Rutas de Importación y Exportación

# %%
db['Route'] = db['origin'].str.cat(db['destination'], sep = '-')
db.head()
# Out:
#             direction origin destination  year      date product  \
# register_id
# 1             Exports  Japan       China  2015  31/01/15    Cars
# 2             Exports  Japan       China  2015  01/02/15    Cars
# 3             Exports  Japan       China  2015  02/02/15    Cars
# 4             Exports  Japan       China  2015  03/02/15    Cars
# 5             Exports  Japan       China  2015  04/02/15    Cars
#
#             transport_mode company_name  total_value        Route
# register_id
# 1                      Sea        Honda     33000000  Japan-China
# 2                      Sea        Honda     16000000  Japan-China
# 3                      Sea        Honda     29000000  Japan-China
# 4                      Sea        Honda     14000000  Japan-China
# 5                      Sea        Honda     17000000  Japan-China

# %%
print(db['Route'].value_counts())
# Out:
# South Korea-Vietnam    497
# Netherlands-Belgium    437
# USA-Netherlands        436
# Japan-Mexico           385
# China-Mexico           351
#                       ...
# France-Russia           13
# Japan-India              8
# France-Austria           7
# Brazil-Germany           6
# Malaysia-Singapore       4
# Name: Route, Length: 172, dtype: int64

# %%
dbimports = db.loc[db['direction'] == 'Imports']
dbexports = db.loc[db['direction'] == 'Exports']

# %%
dbexports['Route'].groupby(db['direction']).value_counts().head(10)
# Out:
# direction  Route
# Exports    South Korea-Vietnam    497
#            Netherlands-Belgium    437
#            USA-Netherlands        436
#            China-Mexico           330
#            Japan-Brazil           306
#            Germany-France         299
#            South Korea-Japan      279
#            Australia-Singapore    273
#            Canada-Mexico          261
#            China-Spain            250
# Name: Route, dtype: int64

# %%
dbimports['Route'].groupby(db['direction']).value_counts().head(10)
# Out:
# direction  Route
# Imports    Singapore-Thailand            273
#            Germany-China                 233
#            China-Japan                   210
#            Japan-Mexico                  206
#            China-Thailand                200
#            Malaysia-Thailand             195
#            Spain-Germany                 142
#            Mexico-USA                    122
#            China-United Arab Emirates    114
#            Brazil-China                  113
# Name: Route, dtype: int64

# %% [markdown]
# ## Ingresos por medio de transporte

# %%
"""Forma no tan elegante de encontrar los ingresos por cada medio de transporte"""

dbt = db[["transport_mode","total_value"]]
tm = dbt.groupby("transport_mode").sum()
tm.sort_values(by = ['total_value'], ascending = False).style.format('${0:,.2f}')
# Out:
# <style type="text/css">
# </style>
# <table id="T_25c2f_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >total_value</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >transport_mode</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_25c2f_level0_row0" class="row_heading level0 row0" >Sea</th>
#       <td id="T_25c2f_row0_col0" class="data row0 col0" >$100,530,622,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_25c2f_level0_row1" class="row_heading level0 row1" >Rail</th>
#       <td id="T_25c2f_row1_col0" class="data row1 col0" >$43,628,043,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_25c2f_level0_row2" class="row_heading level0 row2" >Air</th>
#       <td id="T_25c2f_row2_col0" class="data row2 col0" >$38,262,147,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_25c2f_level0_row3" class="row_heading level0 row3" >Road</th>
#       <td id="T_25c2f_row3_col0" class="data row3 col0" >$33,270,486,000.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
"""Este es el valor total de importaciones y exportaciones"""
total = tm['total_value'].sum()
currency = "${:,.2f}".format(total)
eighty_percent = total*0.8
currency2 = "${:,.2f}".format(eighty_percent)
print(f'El total de las exportaciones e importaciones es de:',currency)
print(f'El 80% de los ingresos es de:', currency2)
# Out:
# El total de las exportaciones e importaciones es de: $215,691,298,000.00
# El 80% de los ingresos es de: $172,553,038,400.00

# %% [markdown]
# ### Ingresos por cada medio de transporte (Exportaciones)

# %%
dbte = dbexports[["transport_mode","total_value"]]
tme = dbte.groupby("transport_mode").sum()
tme.sort_values(by = ['total_value'], ascending = False).style.format('${0:,.2f}')
# Out:
# <style type="text/css">
# </style>
# <table id="T_b070e_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >total_value</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >transport_mode</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b070e_level0_row0" class="row_heading level0 row0" >Sea</th>
#       <td id="T_b070e_row0_col0" class="data row0 col0" >$65,592,622,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_b070e_level0_row1" class="row_heading level0 row1" >Rail</th>
#       <td id="T_b070e_row1_col0" class="data row1 col0" >$34,505,043,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_b070e_level0_row2" class="row_heading level0 row2" >Air</th>
#       <td id="T_b070e_row2_col0" class="data row2 col0" >$32,785,147,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_b070e_level0_row3" class="row_heading level0 row3" >Road</th>
#       <td id="T_b070e_row3_col0" class="data row3 col0" >$27,280,486,000.00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Ingresos por cada medio de transporte (Importaciones)

# %%
dbti = dbimports[["transport_mode","total_value"]]
tmi = dbti.groupby("transport_mode").sum()
tmi.sort_values(by = ['total_value'], ascending = False).style.format('${0:,.2f}')
# Out:
# <style type="text/css">
# </style>
# <table id="T_a2649_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >total_value</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >transport_mode</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a2649_level0_row0" class="row_heading level0 row0" >Sea</th>
#       <td id="T_a2649_row0_col0" class="data row0 col0" >$34,938,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_a2649_level0_row1" class="row_heading level0 row1" >Rail</th>
#       <td id="T_a2649_row1_col0" class="data row1 col0" >$9,123,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_a2649_level0_row2" class="row_heading level0 row2" >Road</th>
#       <td id="T_a2649_row2_col0" class="data row2 col0" >$5,990,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_a2649_level0_row3" class="row_heading level0 row3" >Air</th>
#       <td id="T_a2649_row3_col0" class="data row3 col0" >$5,477,000,000.00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Valor total de Importaciones y exportaciones

# %% [markdown]
# ### Valor total de las exportaciones

# %%
dbt1 = dbexports[["Route","total_value"]]
tm1 = dbt1.groupby("Route").sum()
tm1.sort_values(by = ['total_value'], ascending = False).style.format('${0:,.2f}')
# Out:
# <style type="text/css">
# </style>
# <table id="T_f2377_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >total_value</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Route</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f2377_level0_row0" class="row_heading level0 row0" >China-Mexico</th>
#       <td id="T_f2377_row0_col0" class="data row0 col0" >$12,250,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_f2377_level0_row1" class="row_heading level0 row1" >Canada-Mexico</th>
#       <td id="T_f2377_row1_col0" class="data row1 col0" >$8,450,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_f2377_level0_row2" class="row_heading level0 row2" >South Korea-Vietnam</th>
#       <td id="T_f2377_row2_col0" class="data row2 col0" >$6,877,007,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_f2377_level0_row3" class="row_heading level0 row3" >France-Belgium</th>
#       <td id="T_f2377_row3_col0" class="data row3 col0" >$5,538,069,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_f2377_level0_row4" class="row_heading level0 row4" >France-United Kingdom</th>
#       <td id="T_f2377_row4_col0" class="data row4 col0" >$5,427,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_f2377_level0_row5" class="row_heading level0 row5" >China-South Korea</th>
#       <td id="T_f2377_row5_col0" class="data row5 col0" >$4,790,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_f2377_level0_row6" class="row_heading level0 row6" >USA-Mexico</th>
#       <td id="T_f2377_row6_col0" class="data row6 col0" >$4,710,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_f2377_level0_row7" class="row_heading level0 row7" >South Korea-Japan</th>
#       <td id="T_f2377_row7_col0" class="data row7 col0" >$4,594,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_f2377_level0_row8" class="row_heading level0 row8" >Germany-Italy</th>
#       <td id="T_f2377_row8_col0" class="data row8 col0" >$4,541,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_f2377_level0_row9" class="row_heading level0 row9" >China-Germany</th>
#       <td id="T_f2377_row9_col0" class="data row9 col0" >$4,090,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_f2377_level0_row10" class="row_heading level0 row10" >China-USA</th>
#       <td id="T_f2377_row10_col0" class="data row10 col0" >$3,797,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_f2377_level0_row11" class="row_heading level0 row11" >Russia-Belorussia</th>
#       <td id="T_f2377_row11_col0" class="data row11 col0" >$3,529,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_f2377_level0_row12" class="row_heading level0 row12" >France-USA</th>
#       <td id="T_f2377_row12_col0" class="data row12 col0" >$3,402,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_f2377_level0_row13" class="row_heading level0 row13" >Japan-Brazil</th>
#       <td id="T_f2377_row13_col0" class="data row13 col0" >$3,368,155,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_f2377_level0_row14" class="row_heading level0 row14" >Netherlands-Belgium</th>
#       <td id="T_f2377_row14_col0" class="data row14 col0" >$3,238,142,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_f2377_level0_row15" class="row_heading level0 row15" >USA-Argentina</th>
#       <td id="T_f2377_row15_col0" class="data row15 col0" >$3,159,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_f2377_level0_row16" class="row_heading level0 row16" >Germany-France</th>
#       <td id="T_f2377_row16_col0" class="data row16 col0" >$2,902,214,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_f2377_level0_row17" class="row_heading level0 row17" >China-Japan</th>
#       <td id="T_f2377_row17_col0" class="data row17 col0" >$2,654,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_f2377_level0_row18" class="row_heading level0 row18" >Japan-China</th>
#       <td id="T_f2377_row18_col0" class="data row18 col0" >$2,550,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_f2377_level0_row19" class="row_heading level0 row19" >USA-Canada</th>
#       <td id="T_f2377_row19_col0" class="data row19 col0" >$2,412,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_f2377_level0_row20" class="row_heading level0 row20" >USA-Brazil</th>
#       <td id="T_f2377_row20_col0" class="data row20 col0" >$2,384,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_f2377_level0_row21" class="row_heading level0 row21" >USA-Belgium</th>
#       <td id="T_f2377_row21_col0" class="data row21 col0" >$2,371,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_f2377_level0_row22" class="row_heading level0 row22" >Russia-China</th>
#       <td id="T_f2377_row22_col0" class="data row22 col0" >$2,310,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_f2377_level0_row23" class="row_heading level0 row23" >Germany-China</th>
#       <td id="T_f2377_row23_col0" class="data row23 col0" >$2,167,875,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_f2377_level0_row24" class="row_heading level0 row24" >Russia-Germany</th>
#       <td id="T_f2377_row24_col0" class="data row24 col0" >$2,042,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_f2377_level0_row25" class="row_heading level0 row25" >Japan-USA</th>
#       <td id="T_f2377_row25_col0" class="data row25 col0" >$1,965,040,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_f2377_level0_row26" class="row_heading level0 row26" >Russia-Netherlands</th>
#       <td id="T_f2377_row26_col0" class="data row26 col0" >$1,959,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_f2377_level0_row27" class="row_heading level0 row27" >France-Germany</th>
#       <td id="T_f2377_row27_col0" class="data row27 col0" >$1,940,035,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_f2377_level0_row28" class="row_heading level0 row28" >Japan-Mexico</th>
#       <td id="T_f2377_row28_col0" class="data row28 col0" >$1,911,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_f2377_level0_row29" class="row_heading level0 row29" >China-Spain</th>
#       <td id="T_f2377_row29_col0" class="data row29 col0" >$1,862,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_f2377_level0_row30" class="row_heading level0 row30" >South Korea-China</th>
#       <td id="T_f2377_row30_col0" class="data row30 col0" >$1,704,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_f2377_level0_row31" class="row_heading level0 row31" >Belgium-United Kingdom</th>
#       <td id="T_f2377_row31_col0" class="data row31 col0" >$1,632,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_f2377_level0_row32" class="row_heading level0 row32" >USA-Singapore</th>
#       <td id="T_f2377_row32_col0" class="data row32 col0" >$1,599,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_f2377_level0_row33" class="row_heading level0 row33" >France-Spain</th>
#       <td id="T_f2377_row33_col0" class="data row33 col0" >$1,455,058,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_f2377_level0_row34" class="row_heading level0 row34" >Russia-Turkey</th>
#       <td id="T_f2377_row34_col0" class="data row34 col0" >$1,446,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_f2377_level0_row35" class="row_heading level0 row35" >Italy-Germany</th>
#       <td id="T_f2377_row35_col0" class="data row35 col0" >$1,415,088,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_f2377_level0_row36" class="row_heading level0 row36" >United Kingdom-Spain</th>
#       <td id="T_f2377_row36_col0" class="data row36 col0" >$1,378,025,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_f2377_level0_row37" class="row_heading level0 row37" >China-Argentina</th>
#       <td id="T_f2377_row37_col0" class="data row37 col0" >$1,236,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_f2377_level0_row38" class="row_heading level0 row38" >South Korea-USA</th>
#       <td id="T_f2377_row38_col0" class="data row38 col0" >$1,228,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_f2377_level0_row39" class="row_heading level0 row39" >Japan-South Korea</th>
#       <td id="T_f2377_row39_col0" class="data row39 col0" >$1,226,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_f2377_level0_row40" class="row_heading level0 row40" >Spain-

# %%
total1 = tm1['total_value'].sum()
currency3 = "${:,.2f}".format(total1)
eighty_percent1 = total1*0.8
currency4 = "${:,.2f}".format(eighty_percent1)
p_general = total1*100/total
moneda = "${:,.2f}".format(p_general)
print(f'El total de las exportaciones es de:',currency3)
#print(f'El 80% de los ingresos es de:', currency4)
print(f'Y representa el {round(p_general,2)} % de los ingresos generales')
# Out:
# El total de las exportaciones es de: $160,163,298,000.00
# Y representa el 74.26 % de los ingresos generales

# %% [markdown]
# ### Valor total de las importaciones

# %%
dbt2 = dbimports[["Route","total_value"]]
tm2 = dbt2.groupby("Route").sum()
tm2.sort_values(by = ['total_value'], ascending = False).style.format('${0:,.2f}')
# Out:
# <style type="text/css">
# </style>
# <table id="T_86931_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >total_value</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Route</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_86931_level0_row0" class="row_heading level0 row0" >Singapore-Thailand</th>
#       <td id="T_86931_row0_col0" class="data row0 col0" >$4,017,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_86931_level0_row1" class="row_heading level0 row1" >Japan-Mexico</th>
#       <td id="T_86931_row1_col0" class="data row1 col0" >$3,918,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_86931_level0_row2" class="row_heading level0 row2" >China-Thailand</th>
#       <td id="T_86931_row2_col0" class="data row2 col0" >$3,831,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_86931_level0_row3" class="row_heading level0 row3" >Malaysia-Thailand</th>
#       <td id="T_86931_row3_col0" class="data row3 col0" >$3,482,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_86931_level0_row4" class="row_heading level0 row4" >China-United Arab Emirates</th>
#       <td id="T_86931_row4_col0" class="data row4 col0" >$3,357,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_86931_level0_row5" class="row_heading level0 row5" >China-Japan</th>
#       <td id="T_86931_row5_col0" class="data row5 col0" >$3,237,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_86931_level0_row6" class="row_heading level0 row6" >Mexico-USA</th>
#       <td id="T_86931_row6_col0" class="data row6 col0" >$2,365,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_86931_level0_row7" class="row_heading level0 row7" >Japan-United Arab Emirates</th>
#       <td id="T_86931_row7_col0" class="data row7 col0" >$2,238,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_86931_level0_row8" class="row_heading level0 row8" >Spain-Germany</th>
#       <td id="T_86931_row8_col0" class="data row8 col0" >$2,044,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_86931_level0_row9" class="row_heading level0 row9" >Germany-Mexico</th>
#       <td id="T_86931_row9_col0" class="data row9 col0" >$1,804,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_86931_level0_row10" class="row_heading level0 row10" >South Korea-United Arab Emirates</th>
#       <td id="T_86931_row10_col0" class="data row10 col0" >$1,713,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_86931_level0_row11" class="row_heading level0 row11" >USA-Germany</th>
#       <td id="T_86931_row11_col0" class="data row11 col0" >$1,620,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_86931_level0_row12" class="row_heading level0 row12" >USA-Thailand</th>
#       <td id="T_86931_row12_col0" class="data row12 col0" >$1,568,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_86931_level0_row13" class="row_heading level0 row13" >Germany-China</th>
#       <td id="T_86931_row13_col0" class="data row13 col0" >$1,328,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_86931_level0_row14" class="row_heading level0 row14" >South Korea-Mexico</th>
#       <td id="T_86931_row14_col0" class="data row14 col0" >$1,291,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_86931_level0_row15" class="row_heading level0 row15" >China-Singapore</th>
#       <td id="T_86931_row15_col0" class="data row15 col0" >$1,267,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_86931_level0_row16" class="row_heading level0 row16" >Mexico-Japan</th>
#       <td id="T_86931_row16_col0" class="data row16 col0" >$1,143,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_86931_level0_row17" class="row_heading level0 row17" >USA-India</th>
#       <td id="T_86931_row17_col0" class="data row17 col0" >$1,133,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_86931_level0_row18" class="row_heading level0 row18" >France-Poland</th>
#       <td id="T_86931_row18_col0" class="data row18 col0" >$1,030,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_86931_level0_row19" class="row_heading level0 row19" >Spain-Mexico</th>
#       <td id="T_86931_row19_col0" class="data row19 col0" >$957,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_86931_level0_row20" class="row_heading level0 row20" >Australia-Japan</th>
#       <td id="T_86931_row20_col0" class="data row20 col0" >$920,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_86931_level0_row21" class="row_heading level0 row21" >Russia-India</th>
#       <td id="T_86931_row21_col0" class="data row21 col0" >$851,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_86931_level0_row22" class="row_heading level0 row22" >Japan-Thailand</th>
#       <td id="T_86931_row22_col0" class="data row22 col0" >$847,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_86931_level0_row23" class="row_heading level0 row23" >South Korea-Germany</th>
#       <td id="T_86931_row23_col0" class="data row23 col0" >$738,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_86931_level0_row24" class="row_heading level0 row24" >Italy-Mexico</th>
#       <td id="T_86931_row24_col0" class="data row24 col0" >$680,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_86931_level0_row25" class="row_heading level0 row25" >Mexico-China</th>
#       <td id="T_86931_row25_col0" class="data row25 col0" >$590,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_86931_level0_row26" class="row_heading level0 row26" >Italy-Poland</th>
#       <td id="T_86931_row26_col0" class="data row26 col0" >$588,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_86931_level0_row27" class="row_heading level0 row27" >Germany-Poland</th>
#       <td id="T_86931_row27_col0" class="data row27 col0" >$570,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_86931_level0_row28" class="row_heading level0 row28" >Canada-USA</th>
#       <td id="T_86931_row28_col0" class="data row28 col0" >$569,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_86931_level0_row29" class="row_heading level0 row29" >Germany-India</th>
#       <td id="T_86931_row29_col0" class="data row29 col0" >$548,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_86931_level0_row30" class="row_heading level0 row30" >Vietnam-United Arab Emirates</th>
#       <td id="T_86931_row30_col0" class="data row30 col0" >$540,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_86931_level0_row31" class="row_heading level0 row31" >Japan-USA</th>
#       <td id="T_86931_row31_col0" class="data row31 col0" >$527,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_86931_level0_row32" class="row_heading level0 row32" >Brazil-China</th>
#       <td id="T_86931_row32_col0" class="data row32 col0" >$413,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_86931_level0_row33" class="row_heading level0 row33" >USA-Japan</th>
#       <td id="T_86931_row33_col0" class="data row33 col0" >$381,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_86931_level0_row34" class="row_heading level0 row34" >United Arab Emirates-India</th>
#       <td id="T_86931_row34_col0" class="data row34 col0" >$371,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_86931_level0_row35" class="row_heading level0 row35" >USA-Canada</th>
#       <td id="T_86931_row35_col0" class="data row35 col0" >$348,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_86931_level0_row36" class="row_heading level0 row36" >Mexico-Germany</th>
#       <td id="T_86931_row36_col0" class="data row36 col0" >$345,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_86931_level0_row37" class="row_heading level0 row37" >China-USA</th>
#       <td id="T_86931_row37_col0" class="data row37 col0" >$297,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_86931_level0_row38" class="row_heading level0 row38" >France-Germany</th>
#       <td id="T_86931_row38_col0" class="data row38 col0" >$286,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_86931_level0_row39" class="row_heading level0 row39" >Japan-Canada</th>
#       <td id="T_86931_row39_col0" class="data row39 col0" >$278,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_86931_level0_row40" class="row_heading level0 row40" >United Kingdom-Canada

# %%
total2 = tm2['total_value'].sum()
currency5 = "${:,.2f}".format(total2)
eighty_percent2 = total2*0.8
currency6 = "${:,.2f}".format(eighty_percent2)
p_generali = total2*100/total
monedita = "${:,.2f}".format(p_generali)
print(f'El total de las importaciones es de:',currency5)
#print(f'El 80% de los ingresos es de:', currency6)
print(f'Y representa el {round(p_generali,2)} % de los ingresos generales')
# Out:
# El total de las importaciones es de: $55,528,000,000.00
# Y representa el 25.74 % de los ingresos generales

# %% [markdown]
# ## Ingresos por país

# %% [markdown]
# ### Exportaciones

# %%
dbta = dbexports[["origin","total_value"]]
tma = dbta.groupby("origin").sum()
tma.rename( columns={ 'total_value' : 'total_exports' } ,inplace=True)
tma.sort_values(by = ['total_exports'], ascending = False).style.format('${0:,.2f}')
# Out:
# <style type="text/css">
# </style>
# <table id="T_7eb66_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >total_exports</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >origin</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7eb66_level0_row0" class="row_heading level0 row0" >China</th>
#       <td id="T_7eb66_row0_col0" class="data row0 col0" >$32,977,046,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_7eb66_level0_row1" class="row_heading level0 row1" >France</th>
#       <td id="T_7eb66_row1_col0" class="data row1 col0" >$18,614,332,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_7eb66_level0_row2" class="row_heading level0 row2" >USA</th>
#       <td id="T_7eb66_row2_col0" class="data row2 col0" >$18,355,306,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_7eb66_level0_row3" class="row_heading level0 row3" >South Korea</th>
#       <td id="T_7eb66_row3_col0" class="data row3 col0" >$14,621,146,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_7eb66_level0_row4" class="row_heading level0 row4" >Russia</th>
#       <td id="T_7eb66_row4_col0" class="data row4 col0" >$13,223,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_7eb66_level0_row5" class="row_heading level0 row5" >Japan</th>
#       <td id="T_7eb66_row5_col0" class="data row5 col0" >$11,948,976,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_7eb66_level0_row6" class="row_heading level0 row6" >Germany</th>
#       <td id="T_7eb66_row6_col0" class="data row6 col0" >$11,343,233,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_7eb66_level0_row7" class="row_heading level0 row7" >Canada</th>
#       <td id="T_7eb66_row7_col0" class="data row7 col0" >$10,684,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_7eb66_level0_row8" class="row_heading level0 row8" >Italy</th>
#       <td id="T_7eb66_row8_col0" class="data row8 col0" >$5,366,684,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_7eb66_level0_row9" class="row_heading level0 row9" >Netherlands</th>
#       <td id="T_7eb66_row9_col0" class="data row9 col0" >$4,120,369,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_7eb66_level0_row10" class="row_heading level0 row10" >Spain</th>
#       <td id="T_7eb66_row10_col0" class="data row10 col0" >$3,418,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_7eb66_level0_row11" class="row_heading level0 row11" >United Kingdom</th>
#       <td id="T_7eb66_row11_col0" class="data row11 col0" >$2,777,612,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_7eb66_level0_row12" class="row_heading level0 row12" >India</th>
#       <td id="T_7eb66_row12_col0" class="data row12 col0" >$2,626,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_7eb66_level0_row13" class="row_heading level0 row13" >Belgium</th>
#       <td id="T_7eb66_row13_col0" class="data row13 col0" >$2,588,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_7eb66_level0_row14" class="row_heading level0 row14" >Brazil</th>
#       <td id="T_7eb66_row14_col0" class="data row14 col0" >$2,274,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_7eb66_level0_row15" class="row_heading level0 row15" >Switzerland</th>
#       <td id="T_7eb66_row15_col0" class="data row15 col0" >$2,154,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_7eb66_level0_row16" class="row_heading level0 row16" >Australia</th>
#       <td id="T_7eb66_row16_col0" class="data row16 col0" >$1,650,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_7eb66_level0_row17" class="row_heading level0 row17" >Mexico</th>
#       <td id="T_7eb66_row17_col0" class="data row17 col0" >$1,419,755,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_7eb66_level0_row18" class="row_heading level0 row18" >Austria</th>
#       <td id="T_7eb66_row18_col0" class="data row18 col0" >$1,155,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_7eb66_level0_row19" class="row_heading level0 row19" >Singapore</th>
#       <td id="T_7eb66_row19_col0" class="data row19 col0" >$684,000.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
tma.shape
# Out:
# (20, 1)

# %% [markdown]
# ### Importaciones

# %%
dbtgh = dbimports[["origin","total_value"]]
tmgh = dbtgh.groupby("origin").sum()
tmgh.rename( columns={ 'total_value' : 'total_imports' } ,inplace=True)
tmgh.sort_values(by = ['total_imports'], ascending = False).style.format('${0:,.2f}')
# Out:
# <style type="text/css">
# </style>
# <table id="T_c5306_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >total_imports</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >origin</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c5306_level0_row0" class="row_heading level0 row0" >China</th>
#       <td id="T_c5306_row0_col0" class="data row0 col0" >$12,233,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_c5306_level0_row1" class="row_heading level0 row1" >Japan</th>
#       <td id="T_c5306_row1_col0" class="data row1 col0" >$8,094,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_c5306_level0_row2" class="row_heading level0 row2" >USA</th>
#       <td id="T_c5306_row2_col0" class="data row2 col0" >$5,291,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_c5306_level0_row3" class="row_heading level0 row3" >Mexico</th>
#       <td id="T_c5306_row3_col0" class="data row3 col0" >$4,621,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_c5306_level0_row4" class="row_heading level0 row4" >Germany</th>
#       <td id="T_c5306_row4_col0" class="data row4 col0" >$4,250,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_c5306_level0_row5" class="row_heading level0 row5" >Singapore</th>
#       <td id="T_c5306_row5_col0" class="data row5 col0" >$4,017,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_c5306_level0_row6" class="row_heading level0 row6" >South Korea</th>
#       <td id="T_c5306_row6_col0" class="data row6 col0" >$3,889,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_c5306_level0_row7" class="row_heading level0 row7" >Malaysia</th>
#       <td id="T_c5306_row7_col0" class="data row7 col0" >$3,560,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_c5306_level0_row8" class="row_heading level0 row8" >Spain</th>
#       <td id="T_c5306_row8_col0" class="data row8 col0" >$3,001,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_c5306_level0_row9" class="row_heading level0 row9" >France</th>
#       <td id="T_c5306_row9_col0" class="data row9 col0" >$1,316,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_c5306_level0_row10" class="row_heading level0 row10" >Italy</th>
#       <td id="T_c5306_row10_col0" class="data row10 col0" >$1,268,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_c5306_level0_row11" class="row_heading level0 row11" >Australia</th>
#       <td id="T_c5306_row11_col0" class="data row11 col0" >$920,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_c5306_level0_row12" class="row_heading level0 row12" >Russia</th>
#       <td id="T_c5306_row12_col0" class="data row12 col0" >$851,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_c5306_level0_row13" class="row_heading level0 row13" >Canada</th>
#       <td id="T_c5306_row13_col0" class="data row13 col0" >$569,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_c5306_level0_row14" class="row_heading level0 row14" >Vietnam</th>
#       <td id="T_c5306_row14_col0" class="data row14 col0" >$540,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_c5306_level0_row15" class="row_heading level0 row15" >Brazil</th>
#       <td id="T_c5306_row15_col0" class="data row15 col0" >$489,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_c5306_level0_row16" class="row_heading level0 row16" >United Arab Emirates</th>
#       <td id="T_c5306_row16_col0" class="data row16 col0" >$371,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_c5306_level0_row17" class="row_heading level0 row17" >United Kingdom</th>
#       <td id="T_c5306_row17_col0" class="data row17 col0" >$248,000,000.00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Cruce de información

# %%
newdf = pd.merge(tma,tmgh, on = 'origin')

# %%
sum_column = newdf['total_exports']+newdf['total_imports']
newdf['Total'] = sum_column
newdf.sort_values(by = ['Total'], ascending = False).style.format('${0:,.2f}')
# Out:
# <style type="text/css">
# </style>
# <table id="T_83093_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >total_exports</th>
#       <th class="col_heading level0 col1" >total_imports</th>
#       <th class="col_heading level0 col2" >Total</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >origin</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_83093_level0_row0" class="row_heading level0 row0" >China</th>
#       <td id="T_83093_row0_col0" class="data row0 col0" >$32,977,046,000.00</td>
#       <td id="T_83093_row0_col1" class="data row0 col1" >$12,233,000,000.00</td>
#       <td id="T_83093_row0_col2" class="data row0 col2" >$45,210,046,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_83093_level0_row1" class="row_heading level0 row1" >USA</th>
#       <td id="T_83093_row1_col0" class="data row1 col0" >$18,355,306,000.00</td>
#       <td id="T_83093_row1_col1" class="data row1 col1" >$5,291,000,000.00</td>
#       <td id="T_83093_row1_col2" class="data row1 col2" >$23,646,306,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_83093_level0_row2" class="row_heading level0 row2" >Japan</th>
#       <td id="T_83093_row2_col0" class="data row2 col0" >$11,948,976,000.00</td>
#       <td id="T_83093_row2_col1" class="data row2 col1" >$8,094,000,000.00</td>
#       <td id="T_83093_row2_col2" class="data row2 col2" >$20,042,976,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_83093_level0_row3" class="row_heading level0 row3" >France</th>
#       <td id="T_83093_row3_col0" class="data row3 col0" >$18,614,332,000.00</td>
#       <td id="T_83093_row3_col1" class="data row3 col1" >$1,316,000,000.00</td>
#       <td id="T_83093_row3_col2" class="data row3 col2" >$19,930,332,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_83093_level0_row4" class="row_heading level0 row4" >South Korea</th>
#       <td id="T_83093_row4_col0" class="data row4 col0" >$14,621,146,000.00</td>
#       <td id="T_83093_row4_col1" class="data row4 col1" >$3,889,000,000.00</td>
#       <td id="T_83093_row4_col2" class="data row4 col2" >$18,510,146,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_83093_level0_row5" class="row_heading level0 row5" >Germany</th>
#       <td id="T_83093_row5_col0" class="data row5 col0" >$11,343,233,000.00</td>
#       <td id="T_83093_row5_col1" class="data row5 col1" >$4,250,000,000.00</td>
#       <td id="T_83093_row5_col2" class="data row5 col2" >$15,593,233,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_83093_level0_row6" class="row_heading level0 row6" >Russia</th>
#       <td id="T_83093_row6_col0" class="data row6 col0" >$13,223,000,000.00</td>
#       <td id="T_83093_row6_col1" class="data row6 col1" >$851,000,000.00</td>
#       <td id="T_83093_row6_col2" class="data row6 col2" >$14,074,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_83093_level0_row7" class="row_heading level0 row7" >Canada</th>
#       <td id="T_83093_row7_col0" class="data row7 col0" >$10,684,000,000.00</td>
#       <td id="T_83093_row7_col1" class="data row7 col1" >$569,000,000.00</td>
#       <td id="T_83093_row7_col2" class="data row7 col2" >$11,253,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_83093_level0_row8" class="row_heading level0 row8" >Italy</th>
#       <td id="T_83093_row8_col0" class="data row8 col0" >$5,366,684,000.00</td>
#       <td id="T_83093_row8_col1" class="data row8 col1" >$1,268,000,000.00</td>
#       <td id="T_83093_row8_col2" class="data row8 col2" >$6,634,684,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_83093_level0_row9" class="row_heading level0 row9" >Spain</th>
#       <td id="T_83093_row9_col0" class="data row9 col0" >$3,418,000,000.00</td>
#       <td id="T_83093_row9_col1" class="data row9 col1" >$3,001,000,000.00</td>
#       <td id="T_83093_row9_col2" class="data row9 col2" >$6,419,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_83093_level0_row10" class="row_heading level0 row10" >Mexico</th>
#       <td id="T_83093_row10_col0" class="data row10 col0" >$1,419,755,000.00</td>
#       <td id="T_83093_row10_col1" class="data row10 col1" >$4,621,000,000.00</td>
#       <td id="T_83093_row10_col2" class="data row10 col2" >$6,040,755,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_83093_level0_row11" class="row_heading level0 row11" >Singapore</th>
#       <td id="T_83093_row11_col0" class="data row11 col0" >$684,000.00</td>
#       <td id="T_83093_row11_col1" class="data row11 col1" >$4,017,000,000.00</td>
#       <td id="T_83093_row11_col2" class="data row11 col2" >$4,017,684,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_83093_level0_row12" class="row_heading level0 row12" >United Kingdom</th>
#       <td id="T_83093_row12_col0" class="data row12 col0" >$2,777,612,000.00</td>
#       <td id="T_83093_row12_col1" class="data row12 col1" >$248,000,000.00</td>
#       <td id="T_83093_row12_col2" class="data row12 col2" >$3,025,612,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_83093_level0_row13" class="row_heading level0 row13" >Brazil</th>
#       <td id="T_83093_row13_col0" class="data row13 col0" >$2,274,000,000.00</td>
#       <td id="T_83093_row13_col1" class="data row13 col1" >$489,000,000.00</td>
#       <td id="T_83093_row13_col2" class="data row13 col2" >$2,763,000,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_83093_level0_row14" class="row_heading level0 row14" >Australia</th>
#       <td id="T_83093_row14_col0" class="data row14 col0" >$1,650,000,000.00</td>
#       <td id="T_83093_row14_col1" class="data row14 col1" >$920,000,000.00</td>
#       <td id="T_83093_row14_col2" class="data row14 col2" >$2,570,000,000.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
intento = dict(zip(newdf.index,newdf.Total))
sorted_by_value = sorted(intento.items(), key = lambda v: v[1], reverse = True)
sorted_by_value
# Out:
# [('China', 45210046000),
#  ('USA', 23646306000),
#  ('Japan', 20042976000),
#  ('France', 19930332000),
#  ('South Korea', 18510146000),
#  ('Germany', 15593233000),
#  ('Russia', 14074000000),
#  ('Canada', 11253000000),
#  ('Italy', 6634684000),
#  ('Spain', 6419000000),
#  ('Mexico', 6040755000),
#  ('Singapore', 4017684000),
#  ('United Kingdom', 3025612000),
#  ('Brazil', 2763000000),
#  ('Australia', 2570000000)]

# %%
sumita = 0
for k in sorted_by_value:
    if sumita <= eighty_percent:
        moneda1 = "${:,.2f}".format(k[1])
        print(f'{k[0]} tuvo ingresos por: {moneda1} que representa el {round(k[1]/total*100,2)}% de las operaciones')
        sumita += k[1]
moneda2 = "${:,.2f}".format(sumita)
print(f'\nEstos países generaron ingresos por: {moneda2} que representan el {round(sumita/total*100,2)}% del total de los ingresos')
# Out:
# China tuvo ingresos por: $45,210,046,000.00 que representa el 20.96% de las operaciones
# USA tuvo ingresos por: $23,646,306,000.00 que representa el 10.96% de las operaciones
# Japan tuvo ingresos por: $20,042,976,000.00 que representa el 9.29% de las operaciones
# France tuvo ingresos por: $19,930,332,000.00 que representa el 9.24% de las operaciones
# South Korea tuvo ingresos por: $18,510,146,000.00 que representa el 8.58% de las operaciones
# Germany tuvo ingresos por: $15,593,233,000.00 que representa el 7.23% de las operaciones
# Russia tuvo ingresos por: $14,074,000,000.00 que representa el 6.53% de las operaciones
# Canada tuvo ingresos por: $11,253,000,000.00 que representa el 5.22% de las operaciones
# Italy tuvo ingresos por: $6,634,684,000.00 que representa el 3.08% de las operaciones
#
# Estos países generaron ingresos por: $174,894,723,000.00 que representan el 81.09% del total de los ingresos
